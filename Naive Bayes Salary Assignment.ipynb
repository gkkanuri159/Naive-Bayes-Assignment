# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
salary_train=pd.read_csv('SalaryData_Train.csv')

# %%
salary_test=pd.read_csv('SalaryData_Test.csv')

# %%
salary_train.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
salary_test.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
salary_train.shape
# Out:
# (30161, 14)

# %%
salary_test.shape
# Out:
# (15060, 14)

# %%
salary_train.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
salary_test.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
salary_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
salary_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
string_columns=['workclass','education','maritalstatus','occupation','relationship','race','sex','native']

# %%
# Visualization
sns.pairplot(salary_train)
# Out:
# /Users/snehakoneru/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(salary_test)
# Out:
# /Users/snehakoneru/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Salary', y='hoursperweek', data=salary_train)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Salary', y='hoursperweek', data=salary_test)
plt.show()

# %%
sns.distplot(salary_train['hoursperweek'])
# Out:
# /var/folders/gh/_7nf_xl92bd8fjzld_vp7b8m0000gn/T/ipykernel_1151/555332065.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(salary_train['hoursperweek'])
# <Axes: xlabel='hoursperweek', ylabel='Density'>

# %%
sns.distplot(salary_test['hoursperweek'])
# Out:
# /var/folders/gh/_7nf_xl92bd8fjzld_vp7b8m0000gn/T/ipykernel_1151/947428108.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(salary_test['hoursperweek'])
# <Axes: xlabel='hoursperweek', ylabel='Density'>

# %%
plt.figure(figsize=(15,10))
sns.lmplot(y='capitalgain', x='hoursperweek',data=salary_train)
plt.show()
# Out:
# /Users/snehakoneru/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(15,10))
sns.lmplot(y='capitalgain', x='hoursperweek',data=salary_test)
plt.show()
# Out:
# /Users/snehakoneru/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='Salary', hue='hoursperweek', data=salary_train, kind='count', height=10,aspect=1.5)
# Out:
# /Users/snehakoneru/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='Salary', hue='hoursperweek', data=salary_test, kind='count', height=10,aspect=1.5)
# Out:
# /Users/snehakoneru/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.subplots(1,2, figsize=(16,8))

colors = ["#FA5858", "#64FE2E"]
labels ="capitalgain", "capitalloss"

plt.suptitle('salary of an individual', fontsize=20)

salary_train["Salary"].value_counts().plot.pie(explode=[0,0.25], autopct='%1.2f%%', shadow=True, colors=colors, 
                                             labels=labels, fontsize=12, startangle=25)
# Out:
# <Axes: ylabel='count'>

# %%
plt.style.use('seaborn-whitegrid')

salary_train.hist(bins=20, figsize=(15,10), color='red')
plt.show()
# Out:
# /var/folders/gh/_7nf_xl92bd8fjzld_vp7b8m0000gn/T/ipykernel_1151/1581221848.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
plt.subplots(1,2, figsize=(16,8))

colors = ["#FA5858", "#64FE2E"]
labels ="capitalgain", "capitalloss"

plt.suptitle('salary of an individual', fontsize=20)

salary_test["Salary"].value_counts().plot.pie(explode=[0,0.25], autopct='%1.2f%%', shadow=True, colors=colors, 
                                             labels=labels, fontsize=12, startangle=25)
# Out:
# <Axes: ylabel='count'>

# %%
plt.style.use('seaborn-whitegrid')

salary_test.hist(bins=20, figsize=(15,10), color='red')
plt.show()
# Out:
# /var/folders/gh/_7nf_xl92bd8fjzld_vp7b8m0000gn/T/ipykernel_1151/638509115.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# Preprocessing
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()

# %%
for i in string_columns:
    salary_train[i]=label_encoder.fit_transform(salary_train[i])
    salary_test[i]=label_encoder.fit_transform(salary_test[i])

# %%
col_names=list(salary_train.columns)
col_names
# Out:
# ['age',
#  'workclass',
#  'education',
#  'educationno',
#  'maritalstatus',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capitalgain',
#  'capitalloss',
#  'hoursperweek',
#  'native',
#  'Salary']

# %%
train_X=salary_train[col_names[0:13]]
train_X
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 0                 1     4    1         2174            0            40      37
# 1                 0     4    1            0            0            13      37
# 2                 1     4    1            0            0            40      37
# 3                 0     2    1            0            0            40      37
# 4                 5     2    0            0            0            40       4
# ...             ...   ...  ...          ...          ...           ...     ...
# 30156             5     4    0            0            0            38      37
# 30157             0     4    1            0            0            40      37
# 30158             4     4    0            0            0            40      37
# 30159             3     4    1            0            0            20      37
# 30160             5     4    0        15024            0            40      37
#
# [30161 rows x 13 columns]

# %%
train_Y=salary_train[col_names[13]]
train_Y
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 30156     <=50K
# 30157      >50K
# 30158     <=50K
# 30159     <=50K
# 30160      >50K
# Name: Salary, Length: 30161, dtype: object

# %%
test_x=salary_test[col_names[0:13]]
test_x
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 0                 3     2    1            0            0            40      37
# 1                 0     4    1            0            0            50      37
# 2                 0     4    1            0            0            40      37
# 3                 0     2    1         7688            0            40      37
# 4                 1     4    1            0            0            30      37
# ...             ...   ...  ...          ...          ...           ...     ...
# 15055             3     4    1            0            0            40      37
# 15056             1     4    0            0            0            36      37
# 15057             0     4    1            0            0            50      37
# 15058             3     1    1         5455            0            40      37
# 15059             0     4    1            0            0            60      37
#
# [15060 rows x 13 columns]

# %%
test_y=salary_test[col_names[13]]
test_y
# Out:
# 0         <=50K
# 1         <=50K
# 2          >50K
# 3          >50K
# 4         <=50K
#           ...
# 15055     <=50K
# 15056     <=50K
# 15057     <=50K
# 15058     <=50K
# 15059      >50K
# Name: Salary, Length: 15060, dtype: object

# %%
# # Building a Model of Naive Bayes
# # Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB
Gnbmodel=GaussianNB()

# %%
train_pred_gau=Gnbmodel.fit(train_X,train_Y).predict(train_X)
train_pred_gau
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype='<U6')

# %%
test_pred_gau=Gnbmodel.fit(train_X,train_Y).predict(test_x)
test_pred_gau
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' >50K', ' <=50K'],
#       dtype='<U6')

# %%
train_acc_gau=np.mean(train_pred_gau==train_Y)

# %%
test_acc_gau=np.mean(test_pred_gau==test_y)

# %%
train_acc_gau
# Out:
# 0.7953317197705646

# %%
test_acc_gau
# Out:
# 0.7946879150066402

# %%
# Multinomial Naive Bayes
from sklearn.naive_bayes import MultinomialNB
Mnbmodel=MultinomialNB()

# %%
train_pred_multi=Mnbmodel.fit(train_X,train_Y).predict(train_X)
train_pred_multi
# Out:
# array([' >50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype='<U6')

# %%
test_pred_multi=Mnbmodel.fit(train_X,train_Y).predict(test_x)
test_pred_multi
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' >50K', ' <=50K'],
#       dtype='<U6')

# %%
train_acc_multi=np.mean(train_pred_multi==train_Y)
train_acc_multi
# Out:
# 0.7729186698053778

# %%
test_acc_multi=np.mean(test_pred_multi==test_y)
test_acc_multi
# Out:
# 0.7749667994687915
